# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torchvision

# %matplotlib inline

# %%
# import py script
import preprocessing
import model

# %%
dataset = preprocessing.read_data(directory='new-plant-diseases-dataset')

# %%
batch_im, batch_lab = next(iter(dataset))

# %%
preprocessing.show_image(image=batch_im[:4], label=batch_lab[:4])

# %%
for image, label in dataset:
    print(image.shape)
    model.SkipConnection(3, 20, 100)(image).shape
    break
# Out:
# torch.Size([32, 3, 256, 256])
