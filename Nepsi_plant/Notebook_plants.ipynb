# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torchvision

# %matplotlib inline

# %%
# import py script
import preprocessing

# %%
dataset = preprocessing.read_data(root_directory='new-plant-diseases-dataset')

# %%
batch_im, batch_lab = next(iter(dataset))

# %%
preprocessing.show_image(image=batch_im[:16], label=batch_lab[:16])
